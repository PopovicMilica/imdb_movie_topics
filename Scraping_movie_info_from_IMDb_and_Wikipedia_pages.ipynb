# %%
# Import modules
from bs4 import BeautifulSoup
import os
import pandas as pd
from movie_webscraping_utils import *

# %% [markdown]
# ### 1. Scraping movie info from IMDb and WIKI pages

# %% [markdown]
# In this notebook, we scrape the data about the top rated movies from IMDB and Wikipedia. Later, in a separate Jupyter notebook, we will use this data to build different topic models so we can retrieve latent topics present in movies plots.
#
# First, we access the IMDb page with 250 top rated movies and scrape the urls of each individual movie. Then, we will scrape the basic info from each movie page, such as movie title, genre and realese date, as well as the synopsis page url. We then proceed to the synopsis page and scrape a detailed storyline of each movie, which we will use later to build our topic models. Moreover, we also try to scrape the individual movie plots from the wikipedia pages dedicated to those movies. In the majority of movies, we can find the wiki webpage by simply adding a movie title to the wikipedia homepage. For the rest, we have to tweak the title slightly to get the correct webpage.

# %%
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250%20lang_eng'
# Make HTTP requests and get a content from a given url
html = read_request(url)
soup = BeautifulSoup(html, 'html.parser')

# Scraping web pages for each movie on 250 IMDB top chart list
movie_webpage_list = []
for a in soup.select( 'td.titleColumn a' ):
    url_new = a.get('href')
    url_new = convert_if_relative_url(url, url_new)
    if not is_absolute_url(url_new):
        print('URL not valid')
    movie_webpage_list.append(url_new)

# Check if we downloaded all 250 movie URLs
assert len(movie_webpage_list) == 250

# %%
# Getting English translated titles from the movies
headers = {'Accept-Language': 'en-US, en;q=0.5'}

wiki_url = 'http://en.wikipedia.org/wiki/'
error_log_list = []

count = 1
for movie_url in movie_webpage_list:
    # Getting movie information from IMDB page of each movie
    movie_html = read_request(movie_url, headers=headers)
    movie_soup = BeautifulSoup(movie_html, 'html.parser')
    
    # Scraping movie title, genre and release date
    try:
        title = movie_soup.find(
            'h1', {"data-testid":"hero-title-block__title"}).get_text(strip=True)
    except:
        error_log_list.append('Obtaining the movie title failed ' + movie_url)
        title = None
    try:
        genre = movie_soup.find('div', {"data-testid":"genres"}).get_text(" ")
        genre_list = list(genre.split())
    except:
        error_log_list.append('Obtaining the movie genre failed ' + movie_url)
        genre_list = None
    try:
        release_date = movie_soup.find(
            'li',{"role":"presentation"}).find('span').get_text(" ")
    except:
        error_log_list.append('Obtaining the movie release date failed ' + movie_url)
        release_date = None
    
   
    # Accessing the synopsis page of each movie and scraping the storyline from it
    try:
        synopsis_ulr = movie_soup.find(
            'ul', {"data-testid":"storyline-plot-links"}).find_all('a')[1].get('href')
        synopsis_ulr = convert_if_relative_url(movie_url, synopsis_ulr)
        synopsis_html = read_request(synopsis_ulr)
        synopsis_soup = BeautifulSoup(synopsis_html, 'html.parser')
        synopsis = synopsis_soup.find(
            'ul', {"id":"plot-synopsis-content"}).get_text(" ", strip=True)
        assert (synopsis is not None and synopsis is not "")
    except:
        error_log_list.append('Obtaining the movie synopsis failed ' + movie_url)
        synopsis = None

    # Getting the movie plot from the Wikipedia page
    try:
        movie_url_wiki = os.path.join(wiki_url, title.replace(' ', '_'))
        # Extracting the plot summary
        wiki_plot = extract_wiki_plot(movie_url_wiki)
        assert (wiki_plot is not None and  wiki_plot is not "")
    except:
        wiki_plot = None
        error_log_list.append(title + ' ' + release_date + ' ' + movie_url_wiki)

    # Adding the scraped movie data to 'top_250_movies.csv'
    update_csv_file('top_250_movies.csv',
                    [[count, title, genre_list, release_date, synopsis, wiki_plot]],
                    cols=['rank', 'title', 'genre', 'release_date', 'imdb_synopsis', 'wiki_plot'],
                    folder_path = './data/')
    
    count += 1
# Out:
# top_250_movies.csv file does not exist. Creating new file!
# Read failed: http://en.wikipedia.org/wiki/Léon:_The_Professional
# Read failed: http://en.wikipedia.org/wiki/WALL·E
# Read failed: http://en.wikipedia.org/wiki/Capharnaüm
# Read failed: http://en.wikipedia.org/wiki/Amélie
# Read failed: http://en.wikipedia.org/wiki/Nausicaä_of_the_Valley_of_the_Wind

# %% [markdown]
# ### 2. Inspecting the error logs

# %% [markdown]
# In the cell below, we look at the cases for which scraping the movie data failed. This happened for quite a few movies - 114 in total. When scraping IMDb website, we only encountred problems in the synopsis part of the webpage (with 16 movies in total). On the other hand, there were many more problems when scraping the wiki pages (98 in total). The large number of problems with the wiki pages is due to our often incorrect initial guess for the webpage link - we simply add the movie title to the Wikipedia homepage. So we will need a little bit more effort to scrape the rest of wiki movie plots.

# %%
# Inspecting the error logs
print('Total number of fails: ', len(error_log_list))
print()
print('Number of imdb failed synopsis scraping: ',
      len([i for i in error_log_list if i.startswith('Obtaining ')]))
print([i for i in error_log_list if i.startswith('Obtaining ')])
print()
print('Number of wiki failed plot scraping: ',
      len([i for i in error_log_list if not i.startswith('Obtaining ')]))
print([i for i in error_log_list if not i.startswith('Obtaining ')])
# Out:
# Total number of fails:  114
#
# Number of imdb failed synopsis scraping:  16
# ['Obtaining the movie synopsis failed https://www.imdb.com/title/tt0027977/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt8267604/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0057565/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0091251/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0012349/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0050976/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0476735/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt3011894/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0077711/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0053198/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0116231/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0113247/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt5323662/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt0087544/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt7060344/', 'Obtaining the movie synopsis failed https://www.imdb.com/title/tt3417422/']
#
# Number of wiki failed plot scraping:  98
# ['The Dark Knight 2008 http://en.wikipedia.org/wiki/The_Dark_Knight', '12 Angry Men 1957 http://en.wikipedia.org/wiki/12_Angry_Men', "One Flew Over the Cuckoo's Nest 1975 http://en.wikipedia.org/wiki/One_Flew_Over_the_Cuckoo's_Nest", 'Se7en 1995 http://en.wikipedia.org/wiki/Se7en', 'The Silence of the Lambs 1991 http://en.wikipedia.org/wiki/The_Silence_of_the_Lambs', 'City of God 2002 http://en.wikipedia.org/wiki/City_of_God', 'Interstellar 2014 http://en.wikipedia.org/wiki/Interstellar', 'The Green Mile 1999 http://en.wikipedia.org/wiki/The_Green_Mile', 'Parasite 2019 http://en.wikipedia.org/wiki/Parasite', 'Léon: The Professional 1994 http://en.wikipedia.org/wiki/Léon:_The_Professional', 'Hara-Kiri 1962 http://en.wikipedia.org/wiki/Hara-Kiri', 'The Pianist 2002 http://en.wikipedia.org/wiki/The_Pianist', 'Modern Times 1936 http://en.wikipedia.org/wiki/Modern_Times', 'Psycho 1960 http://en.wikipedia.org/wiki/Psycho', 'Gladiator 2000 http://en.wikipedia.org/wiki/Gladiator', 'Whiplash 2014 http://en.wikipedia.org/wiki/Whiplash', 'Casablanca 1942 http://en.wikipedia.org/wiki/Casablanca', 'Alien 1979 http://en.wikipedia.org/wiki/Alien', 'Memento 2000 http://en.wikipedia.org/wiki/Memento', 'Sunset Blvd. 1950 http://en.wikipedia.org/wiki/Sunset_Blvd.', 'WALL·E 2008 http://en.wikipedia.org/wiki/WALL·E', 'The Shining 1980 http://en.wikipedia.org/wiki/The_Shining', 'Witness for the Prosecution 1957 http://en.wikipedia.org/wiki/Witness_for_the_Prosecution', 'Joker 2019 http://en.wikipedia.org/wiki/Joker', 'Oldboy 2003 http://en.wikipedia.org/wiki/Oldboy', 'Hamilton 2020 http://en.wikipedia.org/wiki/Hamilton', 'Aliens 1986 http://en.wikipedia.org/wiki/Aliens', 'Coco 2017 http://en.wikipedia.org/wiki/Coco', 'Capharnaüm 2018 http://en.wikipedia.org/wiki/Capharnaüm', 'High and Low 1963 http://en.wikipedia.org/wiki/High_and_Low', 'American Beauty 1999 http://en.wikipedia.org/wiki/American_Beauty', 'Amadeus 1984 http://en.wikipedia.org/wiki/Amadeus', 'Pather Panchali 1955 http://en.wikipedia.org/wiki/Pather_Panchali', '2001: A Space Odyssey 1968 http://en.wikipedia.org/wiki/2001:_A_Space_Odyssey', 'M 1931 http://en.wikipedia.org/wiki/M', 'Vertigo 1958 http://en.wikipedia.org/wiki/Vertigo', 'The Hunt 2012 http://en.wikipedia.org/wiki/The_Hunt', 'Lawrence of Arabia 1962 http://en.wikipedia.org/wiki/Lawrence_of_Arabia', 'The Kid 1921 http://en.wikipedia.org/wiki/The_Kid', 'Dangal 2016 http://en.wikipedia.org/wiki/Dangal', 'The Father 2020 http://en.wikipedia.org/wiki/The_Father', 'A Clockwork Orange 1971 http://en.wikipedia.org/wiki/A_Clockwork_Orange', 'Metropolis 1927 http://en.wikipedia.org/wiki/Metropolis', '1917 2019 http://en.wikipedia.org/wiki/1917', 'Amélie 2001 http://en.wikipedia.org/wiki/Amélie', 'Snatch 2000 http://en.wikipedia.org/wiki/Snatch', 'Scarface 1983 http://en.wikipedia.org/wiki/Scarface', 'To Kill a Mockingbird 1962 http://en.wikipedia.org/wiki/To_Kill_a_Mockingbird', 'Up 2009 http://en.wikipedia.org/wiki/Up', 'Heat 1995 http://en.wikipedia.org/wiki/Heat', 'Ran 1985 http://en.wikipedia.org/wiki/Ran', 'Green Book 2018 http://en.wikipedia.org/wiki/Green_Book', 'Downfall 2004 http://en.wikipedia.org/wiki/Downfall', "Howl's Moving Castle 2004 http://en.wikipedia.org/wiki/Howl's_Moving_Castle", 'The Wolf of Wall Street 2013 http://en.wikipedia.org/wiki/The_Wolf_of_Wall_Street', 'The Great Escape 1963 http://en.wikipedia.org/wiki/The_Great_Escape', 'Casino 1995 http://en.wikipedia.org/wiki/Casino', 'A Beautiful Mind 2001 http://en.wikipedia.org/wiki/A_Beautiful_Mind', 'Chinatown 1974 http://en.wikipedia.org/wiki/Chinatown', 'The Elephant Man 1980 http://en.wikipedia.org/wiki/The_Elephant_Man', 'The Thing 1982 http://en.wikipedia.org/wiki/The_Thing', 'Klaus 2019 http://en.wikipedia.org/wiki/Klaus', 'Inside Out 2015 http://en.wikipedia.org/wiki/Inside_Out', 'Wild Strawberries 1957 http://en.wikipedia.org/wiki/Wild_Strawberries', 'Trainspotting 1996 http://en.wikipedia.org/wiki/Trainspotting', 'Jurassic Park 1993 http://en.wikipedi ...

# %% [markdown]
# ### 3. Scraping the movie plots from IMDb pages for the movies that are missing synopsis

# %% [markdown]
# On further inspection of error_logs_list, we can see that all of the errors, encountered when scraping from the IMDb website, are for the movies that do not have a synopsis yet added to the page. So, we scrape their storyline plots instead. The storyline plots are quite shorter than the synopsis, but still contain relevant information about the movie storyline.

# %%
# Loading the partially completed dataset
movies_df = pd.read_csv('./data/top_250_movies.csv')

# Webscraping plot summaries from IMDb for movies without synopsis
for k in [i for i in error_log_list if i.startswith('Obtaining ')]:
    movie_url = k.split()[-1]
    movie_html = read_request(movie_url, headers=headers)
    movie_soup = BeautifulSoup(movie_html, 'html.parser')
    title = movie_soup.find(
            'h1', {"data-testid":"hero-title-block__title"}).get_text(strip=True)
    plot = movie_soup.find(
        'div', {"data-testid":"storyline-plot-summary"}
        ).find('div').find('div').find(text=True, recursive=False)
    if plot is None or "":
        print('Plot scraping failed', movie_url)
        continue
    # Adding wiki plot for the particular movie to movies_df
    add_data_to_df_field(movies_df, movies_df['title'] == title, 
                         'imdb_synopsis', plot)
# Out:
#     rank         title                          genre  release_date  \
# 36    37  Modern Times  ['Comedy', 'Drama', 'Family']          1936
#
#                                         imdb_synopsis wiki_plot
# 36  Chaplin's last 'silent' film, filled with soun...       NaN
#     rank       title      genre  release_date  \
# 76    77  Capharnaüm  ['Drama']          2018
#
#                                         imdb_synopsis wiki_plot
# 76  Capernaüm ("Chaos") tells the story of Zain (Z...       NaN
#     rank         title                          genre  release_date  \
# 78    79  High and Low  ['Crime', 'Drama', 'Mystery']          1963
#
#                                         imdb_synopsis wiki_plot
# 78  A wealthy businessman is told his son has been...       NaN
#     rank         title                         genre  release_date  \
# 95    96  Come and See  ['Drama', 'Thriller', 'War']          1985
#
#                                         imdb_synopsis  \
# 95  The feature film directed by Elem Klimov, shot...
#
#                                             wiki_plot
# 95   In 1943, two Belarusian boys dig in a sand-fi...
#      rank    title                          genre  release_date  \
# 103   104  The Kid  ['Comedy', 'Drama', 'Family']          1921
#
#                                          imdb_synopsis wiki_plot
# 103  The opening title reads: "A comedy with a smil...       NaN
#      rank             title                            genre  release_date  \
# 157   158  The Seventh Seal  ['Drama', 'Fantasy', 'History']          1957
#
#                                          imdb_synopsis  \
# 157  A Knight and his squire are home from the crus...
#
#                                              wiki_plot
# 157  Disillusioned knight Antonius Block and his cy...
#      rank                 title                genre  release_date  \
# 174   175  My Father and My Son  ['Drama', 'Family']          2005
#
#                                          imdb_synopsis  \
# 174  Sadik is one of the rebellious youth who has b...
#
#                                              wiki_plot
# 174  In order to study journalism at Istanbul Unive...
#      rank       title                            genre  release_date  \
# 182   183  Wild Tales  ['Comedy', 'Drama', 'Thriller']          2014
#
#                                          imdb_synopsis wiki_plot
# 182  The film is divided into six segments. (1) "Pa...       NaN
#      rank          title               genre  release_date  \
# 210   211  Autumn Sonata  ['Drama', 'Music']          1978
#
#                                          imdb_synopsis  \
# 210  After having neglected her children for many y...
#
#                                              wiki_plot
# 210  Eva (Liv Ullmann), wife of the village pastor,...
#      rank          title               genre  release_date  \
# 216   217  The 400 Blows  ['Crime', 'Drama']          1959
#
#                                          imdb_synopsis  \
# 216  Seemingly in constant trouble at school, 14-ye...
#
#                                              wiki_plot
# 216  Antoine Doinel is a young boy growing up in Pa...
#      rank       title                           genre  release_date  \
# 218   219  The Bandit  ['Crime', 'Drama', 'Thriller']          1996
#
#                                          imdb_synopsis wiki_plot
# 218  The epic adventures of the legendary Baran the...       NaN
#      rank     title               genre  release_date  \
# 221   222  La Haine  ['Crime', 'Drama']          1995
#
#                                          imdb_synopsis  \
# 221  The film follows three young men and their tim...
#
#                                              wiki_plot
# 221  La Haine opens with a montage of news footage ...
#      rank                      title                   genre  release_date  \
# 231   232  A Silent Voice: The Movie  ['Animation', 'Drama']          2016
#
#                                          imdb_synopsis  \
# 231  The story revolves around Shôko Nishimiya, a g...
#
#                                              wiki_plot
# 231  Japanese high school student Shoya Ishida inte...
#      rank                               title  \
# 236   237  Nausicaä of the Valley of the Wind
#
#                                      genre  release_date  \
# 236  ['Animation', 'Adventure', 'Fantasy']          1984
#
#                                          imdb_synopsis wiki_plot
# 236  An animated fantasy-adventure. Set one thousan...       NaN
#      rank       title                           genre  release_date  \
# 239   240  Raatchasan  ['Action', 'Crime', 'Mystery']          2018
#
#                                          imdb_synopsis  \
# 239  Circumstances force Arun, an aspiring film dir...
#
#                                              wiki_plot
# 239  The film opens with two old men discovering a ...
#      rank     title                           genre  release_date  \
# 247   248  Drishyam  ['Crime', 'Drama', 'Thriller']          2013
#
#                                          imdb_synopsis  \
# 247  Georgekutty (Mohanlal) is a cable TV network o...
#
#                                              wiki_plot
# 247  The film begins with Georgekutty - an man accu...

# %%
# Checking that imdb_synopsis column doesn't contain NaN values
print(movies_df['imdb_synopsis'].isnull().any())
# Out:
# False

# %% [markdown]
# ### 4. Scraping the rest of Wikipedia movie plots

# %% [markdown]
# As we saw when inspecting the error log, we were not able to scrape the Wikipedia movie plots of 98 movies. We used a simple way of forming the movie wiki page urls by concatenating the wikipedia homepage with the name of the film.
# (Example. `http://en.wikipedia.org/wiki/The_Wolf_of_Wall_Street`)
# On further inspection of the movies that were unsucessfully scraped, we can observe two common patterns for their respective wiki urls - the first have `_(film)` after the movie title, while the second have `_(XXXX_film)` where `XXXX` stands for the release year of the film. An example of the first pattern is `http://en.wikipedia.org/wiki/The_Dark_Knight_(film)`, while an example for the second pattern is `http://en.wikipedia.org/wiki/Gladiator_(2000_film)`.

# %%
wiki_error_log_list = []
for error_log in [i for i in error_log_list if not i.startswith('Obtaining ')]:
    wiki_url = error_log.split()[-1]
    title = ' '.join(error_log.split()[0:-2])
    wiki_ulr_modified = wiki_url + '_(film)'
    try:
        # Extracting the plot summary
        wiki_plot = extract_wiki_plot(wiki_ulr_modified)
        assert (wiki_plot is not None and  wiki_plot is not "")
        # Adding wiki plot for the particular movie to movies_df
        add_data_to_df_field(movies_df, movies_df['title'] == title, 
                             'wiki_plot', wiki_plot)
    except:
        wiki_error_log_list.append(error_log)
# Out:
#    rank            title                         genre  release_date  \
# 3     4  The Dark Knight  ['Action', 'Crime', 'Drama']          2008
#
#                                        imdb_synopsis  \
# 3  The movie begins with a gang of men with clown...
#
#                                            wiki_plot
# 3  A gang of criminals rob a Gotham City mob bank...
#     rank                            title      genre  release_date  \
# 17    18  One Flew Over the Cuckoo's Nest  ['Drama']          1975
#
#                                         imdb_synopsis  \
# 17  In 1963 Oregon, Randle Patrick McMurphy (Nicho...
#
#                                             wiki_plot
# 17  In Oregon in 1963, Randle Patrick McMurphy is ...
#     rank  title                          genre  release_date  \
# 19    20  Se7en  ['Crime', 'Drama', 'Mystery']          1995
#
#                                         imdb_synopsis  \
# 19  In an unidentified city of constant rain and u...
#
#                                             wiki_plot
# 19  Soon-to-retire Detective Lieutenant William So...
#     rank                     title                           genre  \
# 20    21  The Silence of the Lambs  ['Crime', 'Drama', 'Thriller']
#
#     release_date                                      imdb_synopsis  \
# 20          1991  Promising FBI Academy student Clarice Starling...
#
#                                             wiki_plot
# 20  In 1990, Clarice Starling is pulled from her F...
#     rank         title                             genre  release_date  \
# 27    28  Interstellar  ['Adventure', 'Drama', 'Sci-Fi']          2014
#
#                                         imdb_synopsis  \
# 27  A group of elderly people are giving interview...
#
#                                             wiki_plot
# 27  In 2067, crop blights and dust storms threaten...
#     rank           title                          genre  release_date  \
# 28    29  The Green Mile  ['Crime', 'Drama', 'Fantasy']          1999
#
#                                         imdb_synopsis  \
# 28  The movie opens with a group of people running...
#
#                                             wiki_plot
# 28  At a Louisiana assisted-living home in 1999, e...
# Read failed: http://en.wikipedia.org/wiki/Léon:_The_Professional_(film)
# Read failed: http://en.wikipedia.org/wiki/Hara-Kiri_(film)
#     rank         title                          genre  release_date  \
# 36    37  Modern Times  ['Comedy', 'Drama', 'Family']          1936
#
#                                         imdb_synopsis  \
# 36  Chaplin's last 'silent' film, filled with soun...
#
#                                             wiki_plot
# 36  The Tramp works on an assembly line, where he ...
#     rank       title                        genre  release_date  \
# 47    48  Casablanca  ['Drama', 'Romance', 'War']          1942
#
#                                         imdb_synopsis  \
# 47  In the early years of World War II, December 1...
#
#                                             wiki_plot
# 47  In December 1941, American expatriate Rick Bla...
#     rank  title                 genre  release_date  \
# 51    52  Alien  ['Horror', 'Sci-Fi']          1979
#
#                                         imdb_synopsis  \
# 51  The opening credits appear in front of a large...
#
#                                             wiki_plot
# 51  The commercial space tug Nostromo is returning...
#     rank    title                    genre  release_date  \
# 53    54  Memento  ['Mystery', 'Thriller']          2000
#
#                                         imdb_synopsis  \
# 53  This is a complex story about Leonard Shelby (...
#
#                                             wiki_plot
# 53  The film starts with a Polaroid photograph of ...
#     rank         title                   genre  release_date  \
# 59    60  Sunset Blvd.  ['Drama', 'Film-Noir']          1950
#
#                                         imdb_synopsis  \
# 59  The film opens with the camera tracking down S...
#
#                                             wiki_plot
# 59  At a mansion on Sunset Boulevard, a group of p...
# Read failed: http://en.wikipedia.org/wiki/WALL·E_(film)
#     rank        title                genre  release_date  \
# 61    62  The Shining  ['Drama', 'Horror']          1980
#
#                                         imdb_synopsis  \
# 61  Former teacher and recovering alcoholic Jack T...
#
#                                             wiki_plot
# 61  Jack Torrance takes a winter caretaker positio...
#     rank   title                              genre  release_date  \
# 73    74  Aliens  ['Action', 'Adventure', 'Sci-Fi']          1986
#
#                                         imdb_synopsis  \
# 73  After the opening credits, we see a spacecraft...
#
#                                             wiki_plot
# 73  Ellen Ripley has been in stasis for 57 years i...
# Read failed: http://en.wikipedia.org/wiki/Capharnaüm_(film)
# Read failed: http://en.wikipedia.org/wiki/High_and_Low_(film)
#     rank            title      genre  release_date  \
# 79    80  American Beauty  ['Drama']          1999
#
#                                         imdb_synopsis  \
# 79  Lester Burnham (Kevin Spacey) is a 42-year-old...
#
#                                             wiki_plot
# 79  Lester Burnham is a middle-aged magazine execu...
#     rank    title                              genre  release_date  \
# 82    83  Amadeus  ['Biography', 'Drama', 'History']          1984
#
#                                         imdb_synopsis  \
# 82  The story begins in 1823 as the elderly Antoni...
#
#                                             wiki_plot
# 82  In the winter of 1823, Antonio Salieri is comm...
#     rank                  title                    genre  release_date  \
# 88    89  2001: A Space Odyssey  ['Adventure', 'Sci-Fi']          1968
#
#                                         imdb_synopsis  \
# 88  To Richard Strauss ' tone poem "Thus Spake Zar...
#
#                                             wiki_plot
# 88  In the prehistoric African veldt, a tribe of h...
#     rank    title                               genre  release_date  \
# 92    93  Vertigo  ['Mystery', 'Romance', 'Thriller']          1958
#
#                                         imdb_synopsis  \
# 92  A woman's face gives way to a kaleidoscope of ...
#
#                                             wiki_plot
# 92  After a rooftop chase, where a fellow policema...
#      rank               title                                genre  \
# 102   103  Lawrence of Arabia  ['Adventure', 'Biography', 'Drama']
#
#      release_date                                      imdb_synopsis  \
# 102          1962  In 1935, T. E. Lawrence (Peter O'Toole) is kil...
#
#                                              wiki_plot
# 102  The film is presented in two parts, divided by...
#      rank   title                             genre  release_date  \
# 104   105  Dangal  ['Action', 'Biography', 'Drama']          2016
#
#                                          imdb_synopsis  \
# 104  Spoiler text The story is said by the voice of...
#
#                                              wiki_plot
# 104  Mahavir Singh Phogat, a former amateur wrestle...
#      rank               title                         genre  release_date  \
# 107   108  A Clockwork Orange  ['Crime', 'Drama', 'Sci-Fi']          1971
#
#                                          imdb_synopsis  \
# 107  "A bit of the old ultra-violence." The story t...
#
#                                              wiki_plot
# 107  In a futuristic Britain, Alex DeLarge is the l...
# Read failed: http://en.wikipedia.org/wiki/Amélie_(film)
#      rank   title                genre  release_date  \
# 117   118  Snatch  ['Comedy', 'Crime']          2000
#
#                                          imdb_synopsis  \
# 117  The film opens as we see boxing promoter Turki...
#
#                                              wiki_plot
# 117  After stealing an 86-carat (17.2 g) diamond in...
#      rank                  title               genre  release_date  \
# 120   121  To Kill a Mockingbird  ['Crime', 'Drama']          1962
#
#                                          imdb_synopsis  \
# 120  The titles appear as a young child babbles whi...
#
#                                              wiki_plot
# 120  The film is narrated by the adult Jean Louise ...
#      rank title                       genre  release_date  \
# 128   129   Ran  ['Action', 'Drama', 'War']          1985
#
#                                          imdb_synopsis  \
# 128  &#12302;&#20081;&#12303; Akira Kurosawa's trea...
#
#                                              wiki_plot
# 128  Hidetora Ichimonji, a powerful though now elde...
#      rank       title                             genre  release_date  \
# 130   131  Green Book  ['Biography', 'Comedy', 'Drama']          2018
#
#                                          imdb_synopsis  \
# 130  New York City, 1962 Tony "Tony Lip" Vallelonga...
#
#                                              wiki_plot
# 130  In 1962 New York City, bouncer Tony Lip search...
#      rank                 title                                 genre  \
# 138   139  Howl's Moving Castle  ['Animation', 'Adventure', 'Family']
#
#      release_date                                      imdb_synopsis  \
# 138          2004  Over a quaint area of land, shrouded by fog, a...
#
#                                              wiki_plot
# 138  Sophie, a young milliner and eldest of three s...
#      rank             title                              genre  release_date  \
# 140   141  The Great Escape  ['Adventure', 'Drama', 'History']          1963
#
#                                          imdb_synopsis  \
# 140  The year is 1943. During World War II, the Ger...
#
#                                              wiki_plot
# 140  In late 1942, having expended enormous resourc...
#      rank   title               genre  release_date  \
# 142   143  Casino  ['Crime', 'Drama']          1995
#
#                                          imdb_synopsis  \
# 142  Martin Scorsese's 1995 film Casino follows the...
#
#                                              wiki_plot
# 142  In 1973, sports handicapper and Mafia associat...
#      rank             title                   genre  release_date  \
# 146   147  A Beautiful Mind  ['Biography', 'Drama']          2001
#
#                                          imdb_synopsis  \
# 146  John Nash ( Russell Crowe ) arrives at Princet...
#
#                                              wiki_plot
# 146  In 1947, John Nash arrives at Princeton Univer...
#      rank             title                   genre  release_date  \
# 158   159  The Elephant Man  ['Biography', 'Drama']          1980
#
#                                          imdb_synopsis  \
# 158  In 19th Century Victorian England, Dr. Frederi...
#
#                                              wiki_plot
# 158  Frederick Treves, a surgeon at the London Hosp...
#      rank  title                                 genre  release_date  \
# 161   162  Klaus  ['Animation', 'Adventure', 'Comedy']          2019
#
#                                          imdb_synopsis  \
# 161  The film begins with a letter being delivered....
#
#                                              wiki_plot
# 161  Jesper Johansson is the lazy, spoiled son of t...
#      rank              title                 genre  release_date  \
# 165   166  Wild Strawberries  ['Drama', 'Romance']          1957
#
#                                          imdb_synopsis  \
# 165  The movie opens when 78-year-old Isak Borg, pl...
#
#                                              wiki_plot
# 165  Grouchy, stubborn, and egotistical Professor I...
#      rank          title      genre  release_date  \
# 169   170  Trainspotting  ['Drama']          1996
#
#                                          imdb_synopsis  \
# 169  Set in Edinburgh, the film begins with Mark Re...
#
#                                              wiki_plot
# 169  Mark Renton, a 26-year-old unemployed heroin a...
#      rank          title                              genre  release_date  \
# 170   171  Jurassic Park  ['Action', 'Adventure', 'Sci-Fi']          1993
#
#                                          imdb_synopsis  \
# 170  The story begins on Isla Nublar, a small islan...
#
#                                              wiki_plot
# 170  Industrialist John Hammond has created a theme...
#      rank               title                            genre  release_date  \
# 176   177  Gone with the Wind  ['Drama', 'History', 'Romance']          1939
#
#                                          imdb_synopsis  \
# 176  The film opens in Tara, a cotton plantation ow...
#
#                                              wiki_plot
# 176  In 1861, on the eve of the American Civil War,...
#      rank       title                            genre  release_date  \
# 182   183  Wild Tales  ['Comedy', 'Drama', 'Thriller']          2014
#
#                                          imdb_synopsis  \
# 182  The film is divided into six segments. (1) "Pa...
#
#                                              wiki_plot
# 182  The film is composed of six short segments: "P...
#      rank                      title                            genre  \
# 193   194  In the Name of the Father  ['Biography', 'Crime', 'Drama']
#
#      release_date                                      imdb_synopsis  \
# 193          1993  Story of Gerry Conlon, purported ringleader of...
#
#                                              wiki_plot
# 193  Gerry Conlon is shown in Belfast stripping lea...
#      rank      title                             genre  release_date  \
# 195   196  Gone Girl  ['Drama', 'Mystery', 'Thriller']          2014
#
#                                          imdb_synopsis  \
# 195  Nick Dunne (Ben Affleck) is stroking the hair ...
#
#                                              wiki_plot
# 195  On their fifth wedding anniversary, writing te...
#      rank             title                              genre  release_date  \
# 203   204  12 Years a Slave  ['Biography', 'Drama', 'History']          2013
#
#                                          imdb_synopsis  \
# 203  The movie opens with a group of slaves receivi...
#
#                                              wiki_plot
# 203  Solomon Northup is a free African-American man...
#      rank                     title                                 genre  \
# 204   205  How to Train Your Dragon  ['Animation', 'Action', 'Adventure']
#
#      release_date                                      imdb_synopsis  \
# 204          2010  A Viking boy called Hiccup (voice: Jay Baruche...
#
#                                              wiki_plot
# 204  The viking village of Clan Berk, located on a ...
#      rank        title                   genre  release_date  \
# 213   214  Stand by Me  ['Adventure', 'Drama']          1986
#
#                                          imdb_synopsis  \
# 213  A man ( Richard Dreyfuss ) sits in his car rea...
#
#                                              wiki_plot
# 213  Writer Gordie Lachance reads in the newspaper ...
#      rank  title                          genre  release_date  \
# 217   218  Logan  ['Action', 'Drama', 'Sci-Fi']          2017
#
#                                          imdb_synopsis  \
# 217  The theatrical release of Logan was preceded b...
#
#                                              wiki_plot
# 217  In 2029, no mutants have been born in 25 years...
#      rank    title             genre  release_date  \
# 220   221  Platoon  ['Drama', 'War']          1986
#
#                                          imdb_synopsis  \
# 220  Chris Taylor (Charlie Sheen) is a young Americ...
#
#                                              wiki_plot
# 220  In 1967, U.S. Army volunteer Chris Taylor arri...
#      rank      title                            genre  release_date  \
# 222   223  Spotlight  ['Biography', 'Crime', 'Drama']          2015
#
#                                          imdb_synopsis  \
# 222  The opening shot shows the text: BASED ON ACTU...
#
#                                              wiki_plot
# 222  In 1976, at a Boston Police station, two polic...
# Read failed: http://en.wikipedia.org/wiki/Gangs_of_Wasseypur_(film)
#      rank          title                              genre  release_date  \
# 229   230  Andrei Rublev  ['Biography', 'Drama', 'History']          1966
#
#                                          imdb_synopsis  \
# 229  Director Andrei Tarkovsky shows the beautiful ...
#
#                                              wiki_plot
# 229  Andrei Rublev is divided into eight episodes, ...
#      rank          title                                genre  release_date  \
# 230   231  Into the Wild  ['Adventure', 'Biography', 'Drama']          2007
#
#                                          imdb_synopsis  \
# 230  A young man leaves his middle class existence ...
#
#                                              wiki_plot
# 230  In April 1992, Christopher McCandless arrives ...
# Read failed: http://en.wikipedia.org/wiki/Nausicaä_of_the_Valley_of_the_Wind_(film)
#      rank               title                               genre  \
# 244   245  The Princess Bride  ['Adventure', 'Family', 'Fantasy']
#
#      release_date                                      imdb_synopsis  \
# 244          1987  Fairy tale story-within-a-story with an all-st...
#
#                                              wiki_plot
# 244  The film is an enactment of a book that a gran...
#      rank    title                 genre  release_date  \
# 245   246  Sunrise  ['Drama', 'Romance']          1927
#
#                                          imdb_synopsis  \
# 245  In the summertime, described as vacation time,...
#
#                                              wiki_plot
# 245  A vacationing Woman from the City (Margaret Li...
# Read failed: http://en.wikipedia.org/wiki/Hera_Pheri_(film)
#      rank         title      genre  release_date  \
# 249   250  Paris, Texas  ['Drama']          1984
#
#                                          imdb_synopsis  \
# 249  The film opens with sweeping shots of the vast...
#
#                                              wiki_plot
# 249  Travis Henderson walks alone through the West ...

# %%
print('Number of remaining movies without wiki_plot:', len(wiki_error_log_list))
# Out:
# Number of remaining movies without wiki_plot: 50

# %%
wiki_error_log_list1 = []
for error_log in wiki_error_log_list:
    wiki_url = error_log.split()[-1]
    title = ' '.join(error_log.split()[0:-2])
    release_date = error_log.split()[-2]
    wiki_ulr_modified = wiki_url + '_(' + release_date + '_film)'
    try:
        # Extracting the plot summary
        wiki_plot = extract_wiki_plot(wiki_ulr_modified)
        assert (wiki_plot is not None and  wiki_plot is not "")
        # Adding wiki plot for the particular movie to movies_df
        add_data_to_df_field(movies_df, movies_df['title'] == title, 
                             'wiki_plot', wiki_plot)
    except:
        wiki_error_log_list1.append(error_log)
# Out:
#    rank         title               genre  release_date  \
# 4     5  12 Angry Men  ['Crime', 'Drama']          1957
#
#                                        imdb_synopsis  \
# 4  In a New York City courthouse, an eighteen-yea...
#
#                                            wiki_plot
# 4  In the overheated jury room of the New York Co...
#     rank        title               genre  release_date  \
# 21    22  City of God  ['Crime', 'Drama']          2002
#
#                                         imdb_synopsis  \
# 21  Taking place over the course of over two decad...
#
#                                             wiki_plot
# 21  The film begins in medias res with an armed ga...
#     rank     title                            genre  release_date  \
# 29    30  Parasite  ['Comedy', 'Drama', 'Thriller']          2019
#
#                                         imdb_synopsis  \
# 29  Ki-woo Kim (Choi Woo-Shik) is a young man livi...
#
#                                             wiki_plot
# 29  The Kim family—father Ki-taek, mother Chung-so...
# Read failed: http://en.wikipedia.org/wiki/Léon:_The_Professional_(1994_film)
# Read failed: http://en.wikipedia.org/wiki/Hara-Kiri_(1962_film)
#     rank        title                            genre  release_date  \
# 32    33  The Pianist  ['Biography', 'Drama', 'Music']          2002
#
#                                         imdb_synopsis  \
# 32  "The Pianist" begins in Warsaw, Poland in Sept...
#
#                                             wiki_plot
# 32  In September 1939, Władysław Szpilman, a Polis...
#     rank   title                              genre  release_date  \
# 37    38  Psycho  ['Horror', 'Mystery', 'Thriller']          1960
#
#                                         imdb_synopsis  \
# 37  In a Phoenix hotel room on a Friday afternoon,...
#
#                                             wiki_plot
# 37  During a Friday afternoon tryst in a Phoenix, ...
#     rank      title                             genre  release_date  \
# 42    43  Gladiator  ['Action', 'Adventure', 'Drama']          2000
#
#                                         imdb_synopsis  \
# 42  Shouting "Roma victor!" as his forces attack, ...
#
#                                             wiki_plot
# 42  In AD 180, Hispano-Roman General Maximus Decim...
#     rank     title               genre  release_date  \
# 43    44  Whiplash  ['Drama', 'Music']          2014
#
#                                         imdb_synopsis  \
# 43  The films opens with Andrew Neimann ( Miles Te...
#
#                                             wiki_plot
# 43  Andrew Neiman is a first-year student at the p...
# Read failed: http://en.wikipedia.org/wiki/WALL·E_(2008_film)
#     rank                        title                          genre  \
# 63    64  Witness for the Prosecution  ['Crime', 'Drama', 'Mystery']
#
#     release_date                                      imdb_synopsis  \
# 63          1957  A few years after War War II, in London, Leona...
#
#                                             wiki_plot
# 63  Sir Wilfrid Robarts, a senior barrister, just ...
#     rank  title                           genre  release_date  \
# 65    66  Joker  ['Crime', 'Drama', 'Thriller']          2019
#
#                                         imdb_synopsis  \
# 65  The story takes place in Gotham City, 1981. Ar...
#
#                                             wiki_plot
# 65  Party clown and aspiring stand-up comedian Art...
#     rank   title                           genre  release_date  \
# 67    68  Oldboy  ['Action', 'Drama', 'Mystery']          2003
#
#                                         imdb_synopsis  \
# 67  The film begins in medias res, with the silhou...
#
#                                             wiki_plot
# 67  In 1988, a businessman named Oh Dae-su is arre...
#     rank title                                genre  release_date  \
# 74    75  Coco  ['Animation', 'Adventure', 'Drama']          2017
#
#                                         imdb_synopsis  \
# 74  In Santa Cecilia, Mexico, Imelda Rivera was th...
#
#                                             wiki_plot
# 74  In Santa Cecilia, Mexico, Miguel dreams of bec...
# Read failed: http://en.wikipedia.org/wiki/Capharnaüm_(2018_film)
#     rank         title                          genre  release_date  \
# 78    79  High and Low  ['Crime', 'Drama', 'Mystery']          1963
#
#                                         imdb_synopsis  \
# 78  A wealthy businessman is told his son has been...
#
#                                             wiki_plot
# 78  A wealthy executive named Kingo Gondo (Toshiro...
# Read failed: http://en.wikipedia.org/wiki/Pather_Panchali_(1955_film)
#     rank title                             genre  release_date  \
# 91    92     M  ['Crime', 'Mystery', 'Thriller']          1931
#
#                                         imdb_synopsis  \
# 91  It's noon. Concerned parents are lined up outs...
#
#                                             wiki_plot
# 91  In Berlin,[9] a group of children are playing ...
#     rank     title      genre  release_date  \
# 94    95  The Hunt  ['Drama']          2012
#
#                                         imdb_synopsis  \
# 94  Lucas (Mads Mikkelsen) is a member of a close-...
#
#                                             wiki_plot
# 94  Lucas is a member of a close-knit Danish Hunti...
#      rank    title                          genre  release_date  \
# 103   104  The Kid  ['Comedy', 'Drama', 'Family']          1921
#
#                                          imdb_synopsis  \
# 103  The opening title reads: "A comedy with a smil...
#
#                                              wiki_plot
# 103  An unmarried mother leaves a charity hospital ...
#      rank       title      genre  release_date  \
# 106   107  The Father  ['Drama']          2020
#
#                                          imdb_synopsis  \
# 106  Anne (Olivia Colman) visits her father Anthony...
#
#                                              wiki_plot
# 106  Anne visits her father Anthony in his flat aft...
#      rank       title                genre  release_date  \
# 108   109  Metropolis  ['Drama', 'Sci-Fi']          1927
#
#                                          imdb_synopsis  \
# 108  (This is the synopsis of the full 150 minute v...
#
#                                              wiki_plot
# 108  In the future, in the Million-acre city of Met...
#      rank title                         genre  release_date  \
# 114   115  1917  ['Drama', 'Thriller', 'War']          2019
#
#                                          imdb_synopsis  \
# 114  On 6 April 1917, aerial reconnaissance has obs...
#
#                                              wiki_plot
# 114  On 6 April 1917, aerial reconnaissance has obs...
# Read failed: http://en.wikipedia.org/wiki/Amélie_(2001_film)
#      rank     title               genre  release_date  \
# 118   119  Scarface  ['Crime', 'Drama']          1983
#
#                                          imdb_synopsis  \
# 118  In May 1980, a Cuban man named Tony Montana ( ...
#
#                                              wiki_plot
# 118  In 1980, Cuban refugee and ex-convict Tony Mon...
#      rank title                                 genre  release_date  \
# 122   123    Up  ['Animation', 'Adventure', 'Comedy']          2009
#
#                                          imdb_synopsis  \
# 122  Young Carl Fredricksen ( Jeremy Leary ), a qui...
#
#                                              wiki_plot
# 122  Young Carl Fredricksen idolizes famous explore...
#      rank title                           genre  release_date  \
# 125   126  Heat  ['Crime', 'Drama', 'Thriller']          1995
#
#                                          imdb_synopsis  \
# 125  An inbound Los Angeles Blue Line train pulls i...
#
#                                              wiki_plot
# 125  Neil McCauley is a professional thief based in...
#      rank     title                              genre  release_date  \
# 132   133  Downfall  ['Biography', 'Drama', 'History']          2004
#
#                                          imdb_synopsis  \
# 132  The film starts out with a short clip from a d...
#
#                                              wiki_plot
# 132  In November 1942, at the Wolf's Lair in East P...
#      rank                    title                            genre  \
# 139   140  The Wolf of Wall Street  ['Biography', 'Crime', 'Drama']
#
#      release_date                                      imdb_synopsis  \
# 139          2013  The movie opens with a TV advertisement for St...
#
#                                              wiki_plot
# 139  In 1987, Jordan Belfort lands a job as a Wall ...
#      rank      title                             genre  release_date  \
# 150   151  Chinatown  ['Drama', 'Mystery', 'Thriller']          1974
#
#                                          imdb_synopsis  \
# 150  Set in 1937 Los Angeles, a private investigato...
#
#                                              wiki_plot
# 150  In 1937, a woman identifying herself as Evelyn...
#      rank      title                            genre  release_date  \
# 159   160  The Thing  ['Horror', 'Mystery', 'Sci-Fi']          1982
#
#                                          imdb_synopsis  \
# 159  In the opening shot, an alien spaceship flies ...
#
#                                              wiki_plot
# 159  In Antarctica, a Norwegian helicopter pursues ...
#      rank       title                                 genre  release_date  \
# 162   163  Inside Out  ['Animation', 'Adventure', 'Comedy']          2015
#
#                                          imdb_synopsis  \
# 162  Riley is a girl born in Minnesota. Five emotio...
#
#                                              wiki_plot
# 162  Within the mind of a girl named Riley are the ...
#      rank    title                         genre  release_date  \
# 172   173  Warrior  ['Action', 'Drama', 'Sport']          2011
#
#                                          imdb_synopsis  \
# 172  Paddy Conlon (Nick Nolte), exits a Pittsburgh ...
#
#                                              wiki_plot
# 172  U.S. Marine Tommy Riordan visits his father, P...
#      rank  title                           genre  release_date  \
# 173   174  Fargo  ['Crime', 'Drama', 'Thriller']          1996
#
#                                          imdb_synopsis  \
# 173  The movie opens with a car towing a new tan Ol...
#
#                                              wiki_plot
# 173  In 1987, Jerry Lundegaard, the sales manager o...
#      rank    title                genre  release_date  \
# 180   181  Stalker  ['Drama', 'Sci-Fi']          1979
#
#                                          imdb_synopsis  \
# 180  A "stalker" is a guide who takes people throug...
#
#                                              wiki_plot
# 180  In the distant future, the protagonist (Alexan...
#      rank        title                              genre  release_date  \
# 181   182  The General  ['Action', 'Adventure', 'Comedy']          1926
#
#                                          imdb_synopsis  \
# 181  The Western & Atlantic Flyer "speeds into Mari...
#
#                                              wiki_plot
# 181  Western & Atlantic Railroad train engineer Joh...
#      rank    title                  genre  release_date  \
# 187   188  Persona  ['Drama', 'Thriller']          1966
#
#                                          imdb_synopsis  \
# 187  Persona begins with images of camera equipment...
#
#                                              wiki_plot
# 187  A projector begins screening a series of image...
#      rank title                  genre  release_date  \
# 189   190  Room  ['Drama', 'Thriller']          2015
#
#                                          imdb_synopsis  \
# 189  The film begins with a young boy with really l...
#
#                                              wiki_plot
# 189  In Akron, Ohio, 24-year-old Joy Newsome and he...
#      rank      title                          genre  release_date  \
# 191   192  Prisoners  ['Crime', 'Drama', 'Mystery']          2013
#
#                                          imdb_synopsis  \
# 191  Keller Dover (Hugh Jackman) and his son Ralph ...
#
#                                              wiki_plot
# 191  In Pennsylvania, Keller Dover, his wife Grace,...
#      rank               title                         genre  release_date  \
# 196   197  To Be or Not to Be  ['Comedy', 'Romance', 'War']          1942
#
#                                          imdb_synopsis  \
# 196  Before the 1939 invasion of Poland by Nazi Ger...
#
#                                              wiki_plot
# 196  The well-known stars of a Warsaw theater compa...
#      rank    title                              genre  release_date  \
# 206   207  Ben-Hur  ['Adventure', 'Drama', 'History']          1959
#
#                                          imdb_synopsis  \
# 206  Judah Ben-Hur (Charlton Heston) is a wealthy m...
#
#                                              wiki_plot
# 206  In the Prologue, a baby is born in Bethlehem a...
#      rank    title      genre  release_date  \
# 211   212  Network  ['Drama']          1976
#
#                                          imdb_synopsis  \
# 211  The following synopsis has mostly been taken f...
#
#                                              wiki_plot
# 211  Howard Beale, longtime evening newscaster for ...
#      rank       title                           genre  release_date  \
# 218   219  The Bandit  ['Crime', 'Drama', 'Thriller']          1996
#
#                                          imdb_synopsis  \
# 218  The epic adventures of the legendary Baran the...
#
#                                              wiki_plot
# 218  After serving a 35-year jail sentence, Baran (...
# Read failed: http://en.wikipedia.org/wiki/Gangs_of_Wasseypur_(2012_film)
#      rank    title                            genre  release_date  \
# 227   228  Rebecca  ['Drama', 'Mystery', 'Romance']          1940
#
#                                          imdb_synopsis  \
# 227  The film begins with a female voiceover: "Last...
#
#                                              wiki_plot
# 227  An inexperienced young woman meets aristocrati...
#      rank title                             genre  release_date  \
# 228   229  Rush  ['Action', 'Biography', 'Drama']          2013
#
#                                          imdb_synopsis  \
# 228  The following is based on a true story. The fi...
#
#                                              wiki_plot
# 228  James Hunt and Niki Lauda are exceptional raci...
# Read failed: http://en.wikipedia.org/wiki/Nausicaä_of_the_Valley_of_the_Wind_(1984_film)
# Read failed: http://en.wikipedia.org/wiki/The_Battle_of_Algiers_(1966_film)
#      rank       title                          genre  release_date  \
# 246   247  Hera Pheri  ['Action', 'Comedy', 'Crime']          2000
#
#                                          imdb_synopsis  \
# 246  The plot revolves around an eccentric trio, co...
#
#                                              wiki_plot
# 246  The film begins with Ghanshyam Tripathi (Sunie...

# %%
print('Number of remaining movies without wiki_plot:', len(wiki_error_log_list1))
print(wiki_error_log_list1)
# Out:
# Number of remaining movies without wiki_plot: 10
# ['Léon: The Professional 1994 http://en.wikipedia.org/wiki/Léon:_The_Professional', 'Hara-Kiri 1962 http://en.wikipedia.org/wiki/Hara-Kiri', 'WALL·E 2008 http://en.wikipedia.org/wiki/WALL·E', 'Hamilton 2020 http://en.wikipedia.org/wiki/Hamilton', 'Capharnaüm 2018 http://en.wikipedia.org/wiki/Capharnaüm', 'Pather Panchali 1955 http://en.wikipedia.org/wiki/Pather_Panchali', 'Amélie 2001 http://en.wikipedia.org/wiki/Amélie', 'Gangs of Wasseypur 2012 http://en.wikipedia.org/wiki/Gangs_of_Wasseypur', 'Nausicaä of the Valley of the Wind 1984 http://en.wikipedia.org/wiki/Nausicaä_of_the_Valley_of_the_Wind', 'The Battle of Algiers 1966 http://en.wikipedia.org/wiki/The_Battle_of_Algiers']

# %% [markdown]
# We are left with 10 movies for which we still need to scrape the movie plot. For 6 of them we need to provide their complete urls as a list (see `movie_url_wiki_list`) and their titles (`movie_title_wiki_list`), because they contain special letter characters. Nevertheless, we can still apply the same function (`extract_wiki_plot`) to scrape their storylines. For the last 4 (`Hamilton`, `Pather_Panchali`, `Gangs of Wasseypur` and `The Battle of Algiers`), we need to scrape indivdually because their HTML webpages are slightly different from the rest of the movies.

# %%
movie_url_wiki_list = ['https://en.wikipedia.org/wiki/L%C3%A9on:_The_Professional',
                       'https://en.wikipedia.org/wiki/Harakiri_(1962_film)',
                       'https://en.wikipedia.org/wiki/WALL-E',
                       'https://en.wikipedia.org/wiki/Capernaum_(film)',
                       'https://en.wikipedia.org/wiki/Am%C3%A9lie',
                       'https://en.wikipedia.org/wiki/Nausica%C3%A4_of_the_Valley_of_the_Wind_(film)']
movie_title_wiki_list = ['Léon: The Professional', 'Hara-Kiri', 'WALL·E',
                         'Capharnaüm', 'Amélie', 'Nausicaä of the Valley of the Wind']

for i in range(len(movie_url_wiki_list)):
    movie_url = movie_url_wiki_list[i]
    title = movie_title_wiki_list[i]
    try:
        # Extracting the plot summary
        wiki_plot = extract_wiki_plot(movie_url)
        assert (wiki_plot is not None and  wiki_plot is not "")
        # Adding wiki plot for the particular movie to movies_df
        add_data_to_df_field(movies_df, movies_df['title'] == title, 'wiki_plot', wiki_plot)
    except:
        print('Plot scraping failed: ', movie_url)
# Out:
#     rank                   title                         genre  release_date  \
# 30    31  Léon: The Professional  ['Action', 'Crime', 'Drama']          1994
#
#                                         imdb_synopsis  \
# 30  Léon (Jean Reno) is a hitman (or "cleaner" as ...
#
#                                             wiki_plot
# 30  Léon is an Italian-American hitman (or "cleane...
#     rank      title                           genre  release_date  \
# 31    32  Hara-Kiri  ['Action', 'Drama', 'Mystery']          1962
#
#                                         imdb_synopsis  \
# 31  "Seppuku," or "Harakiri" has it is known in th...
#
#                                             wiki_plot
# 31  Edo, 1630. Tsugumo Hanshirō arrives at the est...
#     rank   title                                 genre  release_date  \
# 60    61  WALL·E  ['Animation', 'Adventure', 'Family']          2008
#
#                                         imdb_synopsis  \
# 60  A Dystopia in the Future Approximately seven h...
#
#                                             wiki_plot
# 60  In the 29th century, rampant consumerism, corp...
#     rank       title      genre  release_date  \
# 76    77  Capharnaüm  ['Drama']          2018
#
#                                         imdb_synopsis  \
# 76  Capernaüm ("Chaos") tells the story of Zain (Z...
#
#                                             wiki_plot
# 76  Zain El Hajj, a 12-year-old from the slums of ...
#      rank   title                  genre  release_date  \
# 116   117  Amélie  ['Comedy', 'Romance']          2001
#
#                                          imdb_synopsis  \
# 116  Amelie Poulain (Audrey Tautou) is the only chi...
#
#                                              wiki_plot
# 116  Amélie Poulain is born in June 1974 and brough...
#      rank                               title  \
# 236   237  Nausicaä of the Valley of the Wind
#
#                                      genre  release_date  \
# 236  ['Animation', 'Adventure', 'Fantasy']          1984
#
#                                          imdb_synopsis  \
# 236  An animated fantasy-adventure. Set one thousan...
#
#                                              wiki_plot
# 236  One thousand years have passed since the Seven...

# %%
# Scraping the plot for movie `Hamilton`
title = 'Hamilton'
wiki_url = 'https://en.wikipedia.org/wiki/Hamilton_(2020_film)'
# Extracting the plot summary
movie_html_wiki = read_request(wiki_url)
movie_soup_wiki = BeautifulSoup(movie_html_wiki, 'html.parser')
# Extracting the plot summary
tag  = movie_soup_wiki.select_one('#Synopsis').find_parent('h2')
while tag.name != 'p':
    tag = tag.find_next_sibling()
wiki_plot = tag.get_text(" ", strip=True)
assert (wiki_plot is not None and  wiki_plot is not "")
# Adding wiki plot for the particular movie to movies_df
add_data_to_df_field(movies_df, movies_df['title'] == title, 'wiki_plot', wiki_plot)

# Scraping the plot for movie `Pather_Panchali`
title = 'Pather Panchali'
wiki_url = 'https://en.wikipedia.org/wiki/Pather_Panchali'
# Extracting the plot summary
movie_html_wiki = read_request(wiki_url)
movie_soup_wiki = BeautifulSoup(movie_html_wiki, 'html.parser')
# Extracting the plot summary
tag  = movie_soup_wiki.select_one('#Plot_summary').find_parent('h2').find_next_sibling()
wiki_plot = ''
while tag.name == 'p':
    wiki_plot += tag.text.replace('\n', ' ')
    tag = tag.find_next_sibling()
assert (wiki_plot is not None and  wiki_plot is not "")
# Adding wiki plot for the particular movie to movies_df
add_data_to_df_field(movies_df, movies_df['title'] == title, 'wiki_plot', wiki_plot)

# Scraping the plot for movie `The Battle of Algiers`
title = 'The Battle of Algiers'
wiki_url = 'https://en.wikipedia.org/wiki/The_Battle_of_Algiers'
# Extracting the plot summary
movie_html_wiki = read_request(wiki_url)
movie_soup_wiki = BeautifulSoup(movie_html_wiki, 'html.parser')
# Extracting the plot summary
tag  = movie_soup_wiki.select_one('#Subject').find_parent('h2').find_next_sibling()
wiki_plot = ''
while tag.name == 'p':
    wiki_plot += tag.text.replace('\n', ' ')
    tag = tag.find_next_sibling()

assert (wiki_plot is not None and  wiki_plot is not "")
# Adding wiki plot for the particular movie to movies_df
add_data_to_df_field(movies_df, movies_df['title'] == title, 'wiki_plot', wiki_plot)

# Scraping the plot for `Gangs of Wasseypur`. This movie has been
# divided into two parts because of its original length of over 5 hours
# We will scrape the plots for both parts and combine them.
wiki_plot = ''
title = 'Gangs of Wasseypur'
urls_list = ['https://en.wikipedia.org/wiki/Gangs_of_Wasseypur_%E2%80%93_Part_1', 
             'https://en.wikipedia.org/wiki/Gangs_of_Wasseypur_%E2%80%93_Part_2']
select_par_list = [{'id':'Plot'}, {'id':'Plot.5B13.5D'}]
for i in range(2):
    wiki_url = urls_list[i]
    select_par = select_par_list[i]
    # Extracting the plot summary
    movie_html_wiki = read_request(wiki_url)
    movie_soup_wiki = BeautifulSoup(movie_html_wiki, 'html.parser')
    # Extracting the plot summary
    tag  = movie_soup_wiki.find('span', select_par).find_parent('h2').find_next_sibling()
    while tag.name != 'h2':
        if tag.name == 'p':
            wiki_plot += tag.text.replace('\n', ' ')
        tag = tag.find_next_sibling()

assert (wiki_plot is not None and  wiki_plot is not "")
# Adding wiki plot for the particular movie to movies_df
add_data_to_df_field(movies_df, movies_df['title'] == title, 'wiki_plot', wiki_plot)
# Out:
#     rank     title                              genre  release_date  \
# 70    71  Hamilton  ['Biography', 'Drama', 'History']          2020
#
#                                         imdb_synopsis  \
# 70  Act I\nThe orphan Alexander Hamilton leaves hi...
#
#                                             wiki_plot
# 70  Divided in two acts, the musical depicts a dra...
#     rank            title      genre  release_date  \
# 85    86  Pather Panchali  ['Drama']          1955
#
#                                         imdb_synopsis  \
# 85  (Previous content of this page was removed due...
#
#                                             wiki_plot
# 85  In Nischindipur, rural Bengal, in the 1910s, H...
#      rank                  title             genre  release_date  \
# 237   238  The Battle of Algiers  ['Drama', 'War']          1966
#
#                                          imdb_synopsis  \
# 237  The opening scene is of a man who has presumab...
#
#                                              wiki_plot
# 237  The Battle of Algiers reconstructs the events ...
#      rank               title                         genre  release_date  \
# 223   224  Gangs of Wasseypur  ['Action', 'Crime', 'Drama']          2012
#
#                                          imdb_synopsis  \
# 223  Prologue\nIn January 2004 , a gang of heavily ...
#
#                                              wiki_plot
# 223  In January 2004, a gang of heavily armed men s...

# %% [markdown]
# ### 5. Inspect the final movies dataframe and save it as a .csv file

# %% [markdown]
# We look at our `movies_df` dataframe and inspect it for the missing values. Since there are no more movies with the missing information we go ahead and save the dataframe.

# %%
movies_df.head(3)
# Out:
#    rank                     title               genre  release_date  \
# 0     1  The Shawshank Redemption           ['Drama']          1994
# 1     2             The Godfather  ['Crime', 'Drama']          1972
# 2     3    The Godfather: Part II  ['Crime', 'Drama']          1974
#
#                                        imdb_synopsis  \
# 0  In 1947, Andy Dufresne ( Tim Robbins ), a bank...
# 1  In late summer 1945, guests are gathered for t...
# 2  The Godfather Part II presents two parallel st...
#
#                                            wiki_plot
# 0  In 1947 Portland, Maine, banker Andy Dufresne ...
# 1  In 1945 New York City, at his daughter Connie'...
# 2  The film intercuts between events some time af...

# %%
movies_df.isnull().any()
# Out:
# rank             False
# title            False
# genre            False
# release_date     False
# imdb_synopsis    False
# wiki_plot        False
# dtype: bool

# %%
# Saving the dataframe to the folder ./data/
movies_df.to_csv('./data/top_250_movies.csv', index=False)
